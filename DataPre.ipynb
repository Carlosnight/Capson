# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import os

path = '/home/carlos/keras/train/'
model = ResNet50(weights = 'imagenet')
all_preds = []

dogs = [
 'n02085620','n02085782','n02085936','n02086079'
,'n02086240','n02086646','n02086910','n02087046'
,'n02087394','n02088094','n02088238','n02088364'
,'n02088466','n02088632','n02089078','n02089867'
,'n02089973','n02090379','n02090622','n02090721'
,'n02091032','n02091134','n02091244','n02091467'
,'n02091635','n02091831','n02092002','n02092339'
,'n02093256','n02093428','n02093647','n02093754'
,'n02093859','n02093991','n02094114','n02094258'
,'n02094433','n02095314','n02095570','n02095889'
,'n02096051','n02096177','n02096294','n02096437'
,'n02096585','n02097047','n02097130','n02097209'
,'n02097298','n02097474','n02097658','n02098105'
,'n02098286','n02098413','n02099267','n02099429'
,'n02099601','n02099712','n02099849','n02100236'
,'n02100583','n02100735','n02100877','n02101006'
,'n02101388','n02101556','n02102040','n02102177'
,'n02102318','n02102480','n02102973','n02104029'
,'n02104365','n02105056','n02105162','n02105251'
,'n02105412','n02105505','n02105641','n02105855'
,'n02106030','n02106166','n02106382','n02106550'
,'n02106662','n02107142','n02107312','n02107574'
,'n02107683','n02107908','n02108000','n02108089'
,'n02108422','n02108551','n02108915','n02109047'
,'n02109525','n02109961','n02110063','n02110185'
,'n02110341','n02110627','n02110806','n02110958'
,'n02111129','n02111277','n02111500','n02111889'
,'n02112018','n02112137','n02112350','n02112706'
,'n02113023','n02113186','n02113624','n02113712'
,'n02113799','n02113978','n02123045','n02123159','n02123394','n02123597'
,'n02124075','n02125311','n02127052']

cats=[
'n02123045','n02123159','n02123394','n02123597'
,'n02124075','n02125311','n02127052']

all_dogs_cats = dogs
# print(all_dogs_cats)

nodogs_nocats = []
topnum = 50
pred_0 = []

imglist = os.listdir(path)
for file in imglist:
    imgpath = path+file
    img = image.load_img(imgpath, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    pred = decode_predictions(preds, top=topnum)[0]
    all_preds.append(pred)
#     print(pred)
    
    if pred[0][0] not in all_dogs_cats and pred[1][0] not in all_dogs_cats and pred[2][0] not in all_dogs_cats\
    and pred[3][0] not in all_dogs_cats and pred[4][0] not in all_dogs_cats and pred[5][0] not in all_dogs_cats \
    and pred[6][0] not in all_dogs_cats and pred[7][0] not in all_dogs_cats and pred[8][0] not in all_dogs_cats\
    and pred[9][0] not in all_dogs_cats and pred[10][0] not in all_dogs_cats and pred[11][0] not in all_dogs_cats\
    and pred[12][0] not in all_dogs_cats and pred[13][0] not in all_dogs_cats and pred[14][0] not in all_dogs_cats\
    and pred[15][0] not in all_dogs_cats and pred[16][0] not in all_dogs_cats and pred[17][0] not in all_dogs_cats\
    and pred[18][0] not in all_dogs_cats and pred[19][0] not in all_dogs_cats and pred[20][0] not in all_dogs_cats\
    and pred[21][0] not in all_dogs_cats and pred[22][0] not in all_dogs_cats and pred[23][0] not in all_dogs_cats\
    and pred[24][0] not in all_dogs_cats and pred[25][0] not in all_dogs_cats and pred[26][0] not in all_dogs_cats\
    and pred[27][0] not in all_dogs_cats and pred[28][0] not in all_dogs_cats and pred[29][0] not in all_dogs_cats\
    and pred[30][0] not in all_dogs_cats and pred[31][0] not in all_dogs_cats and pred[32][0] not in all_dogs_cats\
    and pred[33][0] not in all_dogs_cats and pred[34][0] not in all_dogs_cats and pred[35][0] not in all_dogs_cats\
    and pred[36][0] not in all_dogs_cats and pred[37][0] not in all_dogs_cats and pred[38][0] not in all_dogs_cats\
    and pred[39][0] not in all_dogs_cats and pred[40][0] not in all_dogs_cats and pred[41][0] not in all_dogs_cats\
    and pred[42][0] not in all_dogs_cats and pred[43][0] not in all_dogs_cats and pred[44][0] not in all_dogs_cats\
    and pred[45][0] not in all_dogs_cats and pred[46][0] not in all_dogs_cats and pred[47][0] not in all_dogs_cats\
    and pred[48][0] not in all_dogs_cats and pred[49][0] not in all_dogs_cats:
        nodogs_nocats.append(file)

# %%
print(all_preds[0][0][1])
# Out:
# Persian_cat

# %%
print(len(nodogs_nocats))
print(nodogs_nocats)
# Out:
# 45
# ['dog.12376.jpg', 'dog.2422.jpg', 'cat.10536.jpg', 'dog.5604.jpg', 'cat.8470.jpg', 'cat.7377.jpg', 'dog.7076.jpg', 'dog.4367.jpg', 'cat.2520.jpg', 'dog.4218.jpg', 'dog.11299.jpg', 'cat.8921.jpg', 'cat.9983.jpg', 'cat.7564.jpg', 'cat.4688.jpg', 'dog.4507.jpg', 'cat.12272.jpg', 'cat.5974.jpg', 'dog.1773.jpg', 'cat.8456.jpg', 'dog.1194.jpg', 'dog.6475.jpg', 'cat.10029.jpg', 'cat.11184.jpg', 'dog.2614.jpg', 'dog.6725.jpg', 'cat.2939.jpg', 'dog.10237.jpg', 'cat.1139.jpg', 'cat.5418.jpg', 'dog.1625.jpg', 'dog.9517.jpg', 'dog.7706.jpg', 'dog.10161.jpg', 'cat.10365.jpg', 'cat.12476.jpg', 'dog.10801.jpg', 'cat.11039.jpg', 'dog.8736.jpg', 'cat.10712.jpg', 'dog.2339.jpg', 'dog.11437.jpg', 'cat.3672.jpg', 'cat.6348.jpg', 'cat.4308.jpg']

# %%
import matplotlib.pyplot as plt
import random
import cv2

# 随机选取6张训练集数据观察
fig = plt.gcf()
fig.set_size_inches(20, 30)
for i in range(0,len(nodogs_nocats)):
#     filename = random.choice(nodogs_nocats)
    filename = nodogs_nocats[i]
    img = cv2.imread(path + filename)
    # 将图像从BGR转换成RGB图像
    img = img[:,:,::-1]
    ax = plt.subplot(9,5,1+i)
    ax.set_title(filename)
    ax.imshow(img)
plt.show()
